# %% [markdown]
# # Préparation des intrants et simulations à large échelle dans HEC-ResSim

# %% [markdown]
# ### Réalisé par Sébastien Langlois

# %%
import os

project_path = '/home/sebastien/.wine/drive_c/users/sebastien/Documents/projet/'

csv_directory = os.path.join(project_path,'01_Intrants/Series_stochastiques/csv/*.csv')
source_config_file = os.path.join(project_path,
                         '02_Calculs/Laminage_STO/01_Modele_ResSIM_reference/rss.conf')
ralt_file = os.path.join(project_path,
                         '02_Calculs/Laminage_STO/01_Modele_ResSIM_reference/inputs/10P07BV.ralt')

type_series = 'STO'

nom_BV_hec=['Inflow Mitchinamecus','Inflow Kiamika','Inflow Mont-Laurier',
    'Inflow Cedar','Inflow High Falls','Inflow Petite Nation','Inflow Masson',
    'Inflow Rideau','Inflow South Nation','Inflow Cabonga','Inflow Baskatong',
    'Inflow Paugan','Inflow Arnprior','Inflow Mountain Chute','Inflow Kamaniskeg',
    'Inflow Bark Lake','Inflow Dumoine','Inflow Mattawa',
    'Inflow Joachims','Inflow Otto Holden','Inflow Kipawa','Inflow Dozois',
    'Inflow Victoria','Inflow Rapide 7','Inflow Rapide 2','Inflow Rabbit Lake',
    'Inflow Lower Notch','Inflow Lady Evelyn','Inflow Mistinikon','Inflow Blanche',
    'Inflow Temiscamingue','Inflow Maniwaki','Inflow Chelsea','Inflow Carillon',
    'Inflow Kinojevis','Inflow des Quinze (Anglier)','Inflow Petawawa','Inflow Chenaux et Noire',
    'Inflow Coulonge','Inflow Bonnechere','Inflow Chat Falls','Inflow Mississippi',
    'Inflow Rouge']

nom_BV_dss = ['MITCHINAMECUS','KIAMIKA','MONT-LAURIER','LAC DU POISSON BLANC',
    'HIGH FALLS','RIVIERE PETITE NATION','MASSON','RIVIERE RIDEAU',
    'RIVIERE SOUTH NATION','CABONGA','BASKATONG','PAUGAN',
    'MADAWASKA-ARNPRIOR','MOUNTAIN CHUTE','KAMANISKEG','BARK LAKE',
    'RIVIERE DUMOINE','RIVIERE MATTAWA','DES JOACHIMS','OTTO HOLDEN',
    'KIPAWA','DOZOIS','LAC VICTORIA ET LAC GRANET','RAPIDE 7',
    'RAPIDE 2','RABBIT LAKE','LOWER NOTCH ET INDIAN CHUTE','LADY EVELYN',
    'MISTINIKON','RIVIERE BLANCHE','LAC TEMISCAMINGUE A ANGLIERS','MANIWAKI',
    'CHELSEA','CARILLON ET HULL','RIVIERE KINOJEVIS','LAC DES QUINZE',
    'RIVIERE PETAWAWA','CHENAUX ET NOIRE','RIVIERE COULONGE','RIVIERE BONNECHERE',
    'CHUTE-DES-CHATS','RIVIERE MISSISSIPPI','RIVIERE ROUGE']

keys_link = dict(zip(nom_BV_hec, nom_BV_dss))

routing_config = {'type_series':type_series,
                  'keys_link':keys_link,
                  'source_ralt_file':ralt_file,
                  'source_config_file':source_config_file}


cluster_config = False

# %%
import pandas as pd

# %%
from distributed import Client, progress
from dask_jobqueue import SLURMCluster
import sys

# # Local functions
# sys.path.append(os.path.abspath(os.path.join('..')))
import laminage as lm

# %% [markdown]
# ## Client Dask

# %%
# change to SLURMCluster for distributed calculation
from dask_jobqueue import SLURMCluster
from distributed import Client
from dask import delayed
import dask.array as da

cluster = SLURMCluster(cores=12,             # Number of cores per job
                       memory='100GB',       # Amount of memory per job
                       # Job scheduler specific keywords
                       walltime='01:00:00',
                       queue="node35")

cluster.adapt(minimum=4, maximum=100)


client =  Client(cluster)


# client =  Client()
# client.cluster
# Out:
# /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38941 instead
#   warnings.warn(
# Task exception was never retrieved
# future: <Task finished name='Task-3601' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpkd9x93_x.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpkd9x93_x.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa8beb6ac0>>, <Task finished name='Task-3599' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpjwzn2g96.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpjwzn2g96.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3605' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp9214g7_g.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp9214g7_g.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3606' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpakc0wdlv.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpakc0wdlv.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa883f5880>>, <Task finished name='Task-3603' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp9ezzgyar.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp9ezzgyar.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
# Task exception was never retrieved
# future: <Task finished name='Task-3611' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmplx088h3z.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmplx088h3z.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa817bcc40>>, <Task finished name='Task-3609' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp4ef9wmt5.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp4ef9wmt5.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3617' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpzzzqtvb9.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: node35\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpzzzqtvb9.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: node35
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa80197460>>, <Task finished name='Task-3616' coro=<SpecCluster._correct_state_internal() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py:300> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp0yyff6_u.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: node35\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp0yyff6_u.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: node35
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3620' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp7ez1qht_.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp7ez1qht_.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa8beb6ac0>>, <Task finished name='Task-3618' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmprodry51y.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmprodry51y.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3623' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpczcer30b.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpczcer30b.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3624' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp5rcznm9n.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp5rcznm9n.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa883f5880>>, <Task finished name='Task-3621' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpm154byl8.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpm154byl8.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
# Task exception was never retrieved
# future: <Task finished name='Task-3627' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmph5qphivf.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmph5qphivf.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa817bcc40>>, <Task finished name='Task-3625' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpch35mica.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpch35mica.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3630' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp60x4_xyt.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: node35\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp60x4_xyt.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: node35
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa80197460>>, <Task finished name='Task-3628' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp1ibd9mw2.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: node35\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp1ibd9mw2.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: node35
# sbatch: error: Batch job submission failed: Invalid partition name specified
# Task exception was never retrieved
# future: <Task finished name='Task-3634' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp22ijenbx.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp22ijenbx.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa8beb6ac0>>, <Task finished name='Task-3632' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmphcswmulu.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmphcswmulu.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3638' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpuyaqry1z.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpuyaqry1z.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3639' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpqkfjnitx.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpqkfjnitx.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa883f5880>>, <Task finished name='Task-3636' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpknvc8esr.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpknvc8esr.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
# Task exception was never retrieved
# future: <Task finished name='Task-3643' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmptn34w76u.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
# ...
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpizpxzif0.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: node35
# sbatch: error: Batch job submission failed: Invalid partition name specified
# Task exception was never retrieved
# future: <Task finished name='Task-3823' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpqoibs0mz.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpqoibs0mz.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa8beb6ac0>>, <Task finished name='Task-3821' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpq4ajcj1d.sh\nstdout:\n\nstderr:\nsbatch: error: CPU count per node can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpq4ajcj1d.sh
# stdout:
#
# stderr:
# sbatch: error: CPU count per node can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3829' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpta43f8id.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpta43f8id.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# Task exception was never retrieved
# future: <Task finished name='Task-3828' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp8ce9nkgo.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp8ce9nkgo.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa883f5880>>, <Task finished name='Task-3826' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp715pvrfn.sh\nstdout:\n\nstderr:\nsbatch: error: Memory specification can not be satisfied\nsbatch: error: Batch job submission failed: Requested node configuration is not available\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp715pvrfn.sh
# stdout:
#
# stderr:
# sbatch: error: Memory specification can not be satisfied
# sbatch: error: Batch job submission failed: Requested node configuration is not available
# Task exception was never retrieved
# future: <Task finished name='Task-3833' coro=<_wrap_awaitable() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py:677> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmpmixhllj9.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/asyncio/tasks.py", line 684, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmpmixhllj9.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7faa817bcc40>>, <Task finished name='Task-3831' coro=<AdaptiveCore.adapt() done, defined at /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /tmp/tmp5ssyv7tc.sh\nstdout:\n\nstderr:\nsbatch: error: invalid partition specified: gen10_24*\nsbatch: error: Batch job submission failed: Invalid partition name specified\n\n')>)
# Traceback (most recent call last):
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/dask_jobqueue/core.py", line 388, in _call
#     raise RuntimeError(
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /tmp/tmp5ssyv7tc.sh
# stdout:
#
# stderr:
# sbatch: error: invalid partition specified: gen10_24*
# sbatch: error: Batch job submission failed: Invalid partition name specified

# %%
client.cluster
# Out:
# VBox(children=(HTML(value='<h2>SLURMCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    …

# %%
bm = lm.BaseManager(project_path=project_path)

# %%
lm.hec.csvtodss._csv_to_dss('/home/sebastien/.wine/drive_c/users/sebastien/Documents/projet/01_Intrants/Series_stochastiques/csv/0019947.csv',
                                    '/home/sebastien/.wine/drive_c/users/sebastien/Documents/projet/01_Intrants/Series_stochastiques/dss/0019947.dss')

# %%
results = bm.csv_to_dss(csv_directory=csv_directory,
                        client=client)
progress(results)
# Out:
# VBox()

# %%
bm.run_test_simulation(routing_config=routing_config,
                       client=client)

# %%
results = bm.run_distributed_simulations_ext(routing_config=routing_config,
                                         client=client)

# %%
import dask
a = client.compute(results)

# %%
client.submit(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cfd61847c1a7> in <module>
# ----> 1 client.submit(results)
#
# /opt/anaconda/share/jupyter/kernels/laminage/lib/python3.8/site-packages/distributed/client.py in submit(self, func, key, workers, resources, retries, priority, fifo_timeout, allow_other_workers, actor, actors, pure, *args, **kwargs)
#    1521         """
#    1522         if not callable(func):
# -> 1523             raise TypeError("First input to submit must be a callable function")
#    1524
#    1525         actor = actor or actors
#
# TypeError: First input to submit must be a callable function

# %%
results = bm.run_distributed_simulations(routing_config=routing_config,
                                         client=client)
progress(results)
# Out:
# VBox()

# %%
import shutil
import os

input_path = '/home/sebastien/.wine/drive_c/users/sebastien/Documents/projet/01_Intrants/Series_stochastiques/csv/0000001.csv'


for i in range(2,20000):

    output_path = os.path.join('/home/sebastien/.wine/drive_c/users/sebastien/Documents/projet/01_Intrants/Series_stochastiques/csv',
                               "{:07d}".format(i) + '.csv')

    shutil.copy2(input_path, output_path)

# %%
import glob

liste = sorted(glob.glob('/media/slanglois/ssd-2tb/laminage/projet/01_Intrants/Series_stochastiques/dss/*.dss'))[100:200]

N = int(os.path.basename(liste[0]).split('.')[0])-1

# %%
# Out:
# ['0000001.dss',
#  '0000002.dss',
#  '0000003.dss',
#  '0000004.dss',
#  '0000005.dss',
#  '0000006.dss',
#  '0000007.dss',
#  '0000008.dss',
#  '0000009.dss',
#  '0000010.dss',
#  '0000011.dss',
#  '0000012.dss',
#  '0000013.dss',
#  '0000014.dss',
#  '0000015.dss',
#  '0000016.dss',
#  '0000017.dss',
#  '0000018.dss',
#  '0000019.dss',
#  '0000020.dss',
#  '0000021.dss',
#  '0000022.dss',
#  '0000023.dss',
#  '0000024.dss',
#  '0000025.dss',
#  '0000026.dss',
#  '0000027.dss',
#  '0000028.dss',
#  '0000029.dss',
#  '0000030.dss',
#  '0000031.dss',
#  '0000032.dss',
#  '0000033.dss',
#  '0000034.dss',
#  '0000035.dss',
#  '0000036.dss',
#  '0000037.dss',
#  '0000038.dss',
#  '0000039.dss',
#  '0000040.dss',
#  '0000041.dss',
#  '0000042.dss',
#  '0000043.dss',
#  '0000044.dss',
#  '0000045.dss',
#  '0000046.dss',
#  '0000047.dss',
#  '0000048.dss',
#  '0000049.dss',
#  '0000050.dss',
#  '0000051.dss',
#  '0000052.dss',
#  '0000053.dss',
#  '0000054.dss',
#  '0000055.dss',
#  '0000056.dss',
#  '0000057.dss',
#  '0000058.dss',
#  '0000059.dss',
#  '0000060.dss',
#  '0000061.dss',
#  '0000062.dss',
#  '0000063.dss',
#  '0000064.dss',
#  '0000065.dss',
#  '0000066.dss',
#  '0000067.dss',
#  '0000068.dss',
#  '0000069.dss',
#  '0000070.dss',
#  '0000071.dss',
#  '0000072.dss',
#  '0000073.dss',
#  '0000074.dss',
#  '0000075.dss',
#  '0000076.dss',
#  '0000077.dss',
#  '0000078.dss',
#  '0000079.dss',
#  '0000080.dss',
#  '0000081.dss',
#  '0000082.dss',
#  '0000083.dss',
#  '0000084.dss',
#  '0000085.dss',
#  '0000086.dss',
#  '0000087.dss',
#  '0000088.dss',
#  '0000089.dss',
#  '0000090.dss',
#  '0000091.dss',
#  '0000092.dss',
#  '0000093.dss',
#  '0000094.dss',
#  '0000095.dss',
#  '0000096.dss',
#  '0000097.dss',
#  '0000098.dss',
#  '0000099.dss',
#  '0000100.dss']
